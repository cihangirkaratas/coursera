# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
#  __Cihangir Karatas__ Student

# %% [markdown]
# _curious about "How make things better?"_

# %% [markdown]
# The code shows a graph of the salary raise over the year.

# %%
import matplotlib.pyplot as plt
year = [2022, 2023, 2024, 2025]
salary = [8100, 8200, 8300, 8400]
plt.plot(year, salary)
plt.show()

# %% [markdown]
# # Heading 1
# # Heading 2

# %% [markdown]
# | This | is   |
# |------|------|
# |   a  | table|
